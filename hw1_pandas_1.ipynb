# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams["figure.figsize"] = (12,6)

# %% [markdown]
# # NumPy

# %% [markdown]
# **Задача 1**\
# Сгенерировать массив из случайных положительных чисел произвольной длины. Вывести элементы, которые больше среднего арифметического.

# %% [markdown]
# **Задача 2**\
# Сгенерировать массив из 20 случайных элементов, элементы которого лежат в интервале [0, 10].
# + Определить количество элементов, отличающихся от минимального на 5.
# + Найти среднее арифметическое всех четных элементов массива, стоящих на нечетных местах.

# %% [markdown]
# **Задача 3**\
# Сгенерировать матрицу A размером 5 на 5, элементы которой лежат в интервале [1, 10].
# + Возвести в квадрат максимальный элемент матрицы.
# + Все четные числа заменить на 0.

# %% [markdown]
# **Задача 4**\
# Сгенерировать матрицу B размером 5 на 5, элементы которой лежат в интервале [-5, 5]. Отрицательные элементы матрицы заменить на число отрицательных элементов в строке, в которой они находятся.

# %% [markdown]
# # Pandas

# %%
df = pd.read_csv("https://raw.githubusercontent.com/rolandmueller/titanic/main/titanic3.csv")

# %% [markdown]
# **Задание 1**
# + Какой была максимальная цена билета? Медиана?
# + Какова доля выживших?
# + Сколько мужчин / женщин находилось на борту?

# %% [markdown]
# **Задание 2**
# + Выведите распределение переменной __pclass__ для мужчин и женщин.
#     + Сколько мужчин было в первом классе?
#     + Сколько женщин было в третьем классе?
#
# + Создайте новый признак __age_group__, который равен:
#     + 1, если пассажир был моложе 30 лет;
#     + 2, если пассажиру было от 30 до 60 лет;
#     + 3, если пассажир был старше 60 лет.

# %% [markdown]
# **Задание 3**\
# Найдите самое популярное имя среди пассажиров:
# + мужчин;
# + женщин.

# %% [markdown]
# **Задание 4**
# + Выведите данные о всех пассажирах, которые сели в Cherbourg (Embarked='C') и были старше 50 лет.
# + Выведите данные о всех женщинах младше 20 и старше 50 лет.
# + Сколько пассажиров старше 70 лет было на борту?

# %% [markdown]
# **Задание 5**
# + Посчитайте средний возраст среди мужчин и среди женщин.
# + Посчитайте доли выживших в различных возрастных группах (новый признак **AgeGroup**).
# + Найдите максимальную стоимость билета в каждом из ценовых классов.

# %% [markdown]
# **Задание 6**\
# Ответьте на предыдущие вопросы с помощью функции crosstab и метода pivot_table.

# %% [markdown]
# ## Решение:

# %% [markdown]
# Репозиторий на гитхаб: https://github.com/nooncatt/ML-hw.git

# %% [markdown]
# <div style="background:#FFB6C1; padding:10px; border-radius:10px; text-align:center; font-size:24px; font-weight:bold; margin-top:10px;">
#     🔢 NumPy
# </div>

# %%
# Задача 1: Сгенерировать массив из случайных положительных чисел произвольной длины. Вывести элементы, которые 
# больше среднего арифметического.

arr = np.random.uniform(0, 100, 20)  # 20 случайных дробных чисел от 0 до 100
mean = np.mean(arr)  # среднее значение
more_than_mean = [i for i in arr if i>mean]  # создаем лист компрехеншн|либо используя numpy: more_than_mean = arr[arr > mean]
print(f"Массив: {arr} \n")
print(f"Среднее значение: {mean} \n")
print(f"Элементы больше среднего: {more_than_mean}")
# Out:
# Массив: [55.19058036 40.41279594  0.73149332 75.66060935 56.39050281 42.41834655
#   7.79315857 91.68453142 63.76702883 45.94938145  8.85862612 72.03280989
#  92.65637044 60.67860647 31.80791862 52.5691722  84.90970074 70.3297888
#   1.44850913 91.7626263 ]
#
# Среднее значение: 52.35262786465462
#
# Элементы больше среднего: [55.190580356148644, 75.66060934634996, 56.3905028085877, 91.68453142414033, 63.767028825567294, 72.03280988544735, 92.65637043512913, 60.6786064723261, 52.56917219856887, 84.9097007417931, 70.32978880490084, 91.76262629636534]

# %%
# Задача 2: Сгенерировать массив из 20 случайных элементов, элементы которого лежат в интервале [0, 10].
# Определить количество элементов, отличающихся от минимального на 5.
# Найти среднее арифметическое всех четных элементов массива, стоящих на нечетных местах.

arr_20 = np.random.randint(0, 11, 20)

min_elem = np.min(arr_20)
diff_5 = np.sum(np.abs(arr_20 - min_elem) == 5)

even_numbers_at_odd = [arr_20[i] for i in range(1, len(arr_20), 2) if arr_20[i] % 2 == 0]
mean_even_odd = np.mean(even_numbers_at_odd) # if even_numbers_at_odd else None

print(f"Случайный массив: {arr_20}")
print(f"Количество элементов, отличающихся от минимального на 5: {diff_5}")
print(f"Среднее арифметическое четных элементов на нечетных местах: {mean_even_odd:.2f}")
# Out:
# Случайный массив: [5 8 7 5 9 3 7 9 9 4 0 10 4 8 0 9 8 3 10 8]
# Количество элементов, отличающихся от минимального на 5: 2
# Среднее арифметическое четных элементов на нечетных местах: 7.60

# %%
# Задача 3: Сгенерировать матрицу A размером 5 на 5, элементы которой лежат в интервале [1, 10].
# Возвести в квадрат максимальный элемент матрицы.
# Все четные числа заменить на 0.

matrix_A = np.random.randint(1, 11, (5, 5))
matrix_A
# Out:
# array([[10,  2, 10,  2,  4],
#        [10,  1,  4,  2,  9],
#        [ 2,  5,  8,  5,  2],
#        [ 5,  9,  6,  6,  1],
#        [ 5,  5,  5,  3,  2]])

# %%
max_value = np.max(matrix_A)
matrix_A[matrix_A == max_value] = max_value ** 2  # Возведение в квадрат максимального элемента
matrix_A[matrix_A % 2 == 0] = 0  # Замена четных чисел на 0

print("Модифицированная матрица A:")
matrix_A
# Out:
# Модифицированная матрица A:
# array([[0, 0, 0, 0, 0],
#        [0, 1, 0, 0, 9],
#        [0, 5, 0, 5, 0],
#        [5, 9, 0, 0, 1],
#        [5, 5, 5, 3, 0]])

# %%
# Задача 4: Сгенерировать матрицу B размером 5 на 5, элементы которой лежат в интервале [-5, 5]. 
# Отрицательные элементы матрицы заменить на число отрицательных элементов в строке, в которой они находятся.
matrix_B = np.random.randint(-5, 6, (5, 5))
matrix_B
# Out:
# array([[-1, -2,  0,  1, -4],
#        [-3,  3, -5, -1,  1],
#        [-3, -5, -4,  2,  0],
#        [ 3,  0, -1, -1, -4],
#        [-1,  2, -4,  5,  4]])

# %%
for i in range(matrix_B.shape[0]):
    negative_count = np.sum(matrix_B[i] < 0)
    matrix_B[i][matrix_B[i] < 0] = negative_count  # pамена отриц элементов на их кол-во в строке

print("Модифицированная матрица B:")
print(matrix_B)
# Out:
# Модифицированная матрица B:
# [[3 3 0 1 3]
#  [3 3 3 3 1]
#  [3 3 3 2 0]
#  [3 0 3 3 3]
#  [2 2 2 5 4]]

# %% [markdown]
# <div style="background:#FFD1DC; padding:10px; border-radius:10px; text-align:center; font-size:24px; font-weight:bold;">
#     🐼 Pandas
# </div>

# %%
# загружаем датасет Titanic
df = pd.read_csv("https://raw.githubusercontent.com/rolandmueller/titanic/main/titanic3.csv")
df.head(5)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %% [markdown]
# # Задание 1:
# - Какой была максимальная цена билета? Медиана?
# - Какова доля выживших?
# - Сколько мужчин / женщин находилось на борту?

# %%
max_fare = df['fare'].max()
median_fare = df['fare'].median()

survival_rate = df['survived'].sum() / len(df)
gender_counts = df['sex'].value_counts()

# %%
print(f"Максимальная цена билета: {max_fare}")
print(f"Медианная цена билета: {median_fare}")
print(f"Доля выживших: {survival_rate:.2f}")
print("Количество мужчин и женщин на борту:")
gender_counts
# Out:
# Максимальная цена билета: 512.3292
# Медианная цена билета: 14.4542
# Доля выживших: 0.38
# Количество мужчин и женщин на борту:
# sex
# male      843
# female    466
# Name: count, dtype: int64

# %% [markdown]
# # Задание 2: Распределение pclass для мужчин и женщин
# - Выведите распределение переменной __pclass__ для мужчин и женщин.
# - Сколько мужчин было в первом классе?
# - Сколько женщин было в третьем классе?
#
# ### Создайте новый признак __age_group__, который равен:
# - 1, если пассажир был моложе 30 лет;
# - 2, если пассажиру было от 30 до 60 лет;
# - 3, если пассажир был старше 60 лет.

# %%
pclass_distribution = df.groupby(['sex', 'pclass']).size().unstack()
pclass_distribution
# Out:
# pclass    1    2    3
# sex
# female  144  106  216
# male    179  171  493

# %%
# столбчатая диаграмма
pclass_distribution.plot(kind='bar', figsize=(8,5), colormap='coolwarm', edgecolor='black')

plt.title("Распределение классов Pclass по полу", fontsize=14)
plt.xlabel("Пол", fontsize=12)
plt.ylabel("Количество пассажиров", fontsize=12)
plt.xticks(rotation=0)  # подписи горизонтальны
plt.legend(title="Класс", title_fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
men_in_first_class = df[(df['sex'] == 'male') & (df['pclass'] == 1)].shape[0]
women_in_third_class = df[(df['sex'] == 'female') & (df['pclass'] == 3)].shape[0]

# %%
print(f"Мужчин в первом классе: {men_in_first_class}. Женщин в третьем классе: {women_in_third_class}")
# Out:
# Мужчин в первом классе: 179. Женщин в третьем классе: 216

# %%
# признак age_group
df['age_group'] = pd.cut(df['age'], bins=[0, 30, 60, float('inf')], labels=[1, 2, 3])
df.sample(3)
# Out:
#      pclass  survived                            name     sex   age  sibsp  \
# 772       3         0                 Dika, Mr. Mirko    male  17.0      0
# 943       3         0  Laitinen, Miss. Kristina Sofia  female  37.0      0
# 563       2         0       Slemen, Mr. Richard James    male  35.0      0
#
#      parch  ticket     fare cabin embarked boat  body home.dest age_group  \
# 772      0  349232   7.8958   NaN        S  NaN   NaN       NaN         1
# 943      0    4135   9.5875   NaN        S  NaN   NaN       NaN         2
# 563      0   28206  10.5000   NaN        S  NaN   NaN  Cornwall         2
#
#     first_name
# 772      Mirko
# 943   Kristina
# 563    Richard

# %% [markdown]
# # Задание 3: Самые популярные имена среди мужчин и женщин

# %%
import re

# aункция для извлечения имени
def get_first_name(name):
    match = re.search(r'\(([^)]+)\)', name)  # проверяем, есть ли имя в скобках
    if match:
        return match.group(1).split()[0]  # берём первое слово из скобок (женское имя)
    else:
        return name.split('.')[1].strip().split()[0]  # берём первое слово после титула

# %%
# новый столбец с именами
df['first_name'] = df['name'].apply(get_first_name)
df.sample(3)
# Out:
#       pclass  survived                                    name   sex   age  \
# 1306       3         0               Zakarian, Mr. Mapriededer  male  26.5
# 926        3         1                       Kennedy, Mr. John  male   NaN
# 538        2         1  Portaluppi, Mr. Emilio Ilario Giuseppe  male  30.0
#
#       sibsp  parch      ticket     fare cabin embarked boat   body  \
# 1306      0      0        2656   7.2250   NaN        C  NaN  304.0
# 926       0      0      368783   7.7500   NaN        Q  NaN    NaN
# 538       0      0  C.A. 34644  12.7375   NaN        C   14    NaN
#
#         home.dest age_group   first_name name_cleaned
# 1306          NaN         1  Mapriededer  Mapriededer
# 926           NaN       NaN         John         John
# 538   Milford, NH         1       Emilio       Emilio

# %%
# ппроверяем, самые популярные имена
most_common_male_name = df[df['sex'] == 'male']['first_name'].mode()[0]
most_common_female_name = df[df['sex'] == 'female']['first_name'].mode()[0]

print(f"Самое популярное имя среди мужчин: {most_common_male_name}")
print(f"Самое популярное имя среди женщин: {most_common_female_name}")
# Out:
# Самое популярное имя среди мужчин: William
# Самое популярное имя среди женщин: Mary

# %% [markdown]
# # Задание 4:
# - Выведите данные о всех пассажирах, которые сели в Cherbourg (Embarked='C') и были старше 50 лет.
# - Выведите данные о всех женщинах младше 20 и старше 50 лет.
# - Сколько пассажиров старше 70 лет было на борту?

# %%
cherbourg_passengers_50_plus = df[(df['embarked'] == 'C') & (df['age'] > 50)]
cherbourg_passengers_50_plus.shape[0]
# Out:
# 27

# %%
cherbourg_passengers_50_plus
# Out:
#      pclass  survived                                               name  \
# 9         1         0                            Artagaveytia, Mr. Ramon
# 43        1         1    Bucknell, Mrs. William Robert (Emma Eliza Ward)
# 48        1         1   Candee, Mrs. Edward (Helen Churchill Hungerford)
# 50        1         1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 78        1         1  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
# 104       1         1                     Eustis, Miss. Elizabeth Mussey
# 123       1         1                   Frolicher-Stehli, Mr. Maxmillian
# 135       1         0                          Goldschmidt, Mr. George B
# 136       1         1                          Gracie, Col. Archibald IV
# 174       1         0                            Kent, Mr. Edward Austin
# 186       1         1          Lindstrom, Mrs. Carl Johan (Sigrid Posse)
# 192       1         1                               Lurette, Miss. Elise
# ...

# %%
women_under_20_or_over_50 = df[(df['sex'] == 'female') & ((df['age'] < 20) | (df['age'] > 50))]
women_under_20_or_over_50.shape[0]
# Out:
# 135

# %%
women_under_20_or_over_50
# Out:
#       pclass  survived                                               name  \
# 2          1         0                       Allison, Miss. Helen Loraine
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 27         1         1            Bishop, Mrs. Dickinson H (Helen Walton)
# ...      ...       ...                                                ...
# 1265       3         0                          Van Impe, Miss. Catharina
# 1273       3         0                 Vander Planke, Miss. Augusta Maria
# 1279       3         0               Vestrom, Miss. Hulda Amanda Adolfina
# 1300       3         1            Yasbeck, Mrs. Antoni (Selini Alexander)
# 1304       3         0                               Zabour, Miss. Hileni
#
#          sex   age  sibsp  parch    ticket      fare    cabin embarked boat  \
# ...

# %%
passengers_over_70 = df[df['age'] > 70].shape[0]
print(f"Количество пассажиров старше 70 лет на борту: {passengers_over_70}")
# Out:
# Количество пассажиров старше 70 лет на борту: 6

# %% [markdown]
# # Задание 5:
# - Посчитайте средний возраст среди мужчин и среди женщин.
# - Посчитайте доли выживших в различных возрастных группах (новый признак **AgeGroup**).
# - Найдите максимальную стоимость билета в каждом из ценовых классов.

# %%
average_age_by_gender = df.groupby('sex')['age'].mean()
print("Средний возраст по полу:")
average_age_by_gender
# Out:
# Средний возраст по полу:
# sex
# female    28.687071
# male      30.585233
# Name: age, dtype: float64

# %%
survival_by_age_group = df.groupby('age_group')['survived'].mean()
print("Доля выживших по возрастным группам:")
survival_by_age_group
# Out:
# Доля выживших по возрастным группам:
# C:\Users\User\AppData\Local\Temp\ipykernel_23228\1025838690.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   survival_by_age_group = df.groupby('age_group')['survived'].mean()
# age_group
# 1    0.407225
# 2    0.423267
# 3    0.242424
# Name: survived, dtype: float64

# %%
max_fare_by_class = df.groupby('pclass')['fare'].max()

print("Максимальная стоимость билета по классам:")
max_fare_by_class
# Out:
# Максимальная стоимость билета по классам:
# pclass
# 1    512.3292
# 2     73.5000
# 3     69.5500
# Name: fare, dtype: float64

# %% [markdown]
# # Задание 6: Использование crosstab и pivot_table

# %% [markdown]
# ### - *crosstab()*
#
# Создаёт таблицу частот (счёта) значений между двумя столбцами.
# Используется, когда нужно посчитать взаимосвязь категориальных переменных.
#
# ### - pivot_table()
#
# Гибче, чем crosstab(), позволяет агрегировать данные разными способами.
# Используется, когда нужно группировка + агрегирование (например, среднее, сумма, количество).

# %%
# Доля выживших по полу
survival_by_gender = pd.crosstab(df['sex'], df['survived'], normalize='index')
survival_by_gender
# Out:
# survived         0         1
# sex
# female    0.272532  0.727468
# male      0.809015  0.190985

# %%
# Распределение пассажиров по классам и полу
pclass_distribution_pivot = df.pivot_table(index='sex', columns='pclass', aggfunc='size', fill_value=0)
pclass_distribution_pivot
# Out:
# pclass    1    2    3
# sex
# female  144  106  216
# male    179  171  493

# %%
# Доля выживших в разных возрастных группах
survival_by_age_group = pd.crosstab(df['age_group'], df['survived'], normalize='index')
survival_by_age_group
# Out:
# survived          0         1
# age_group
# 1          0.592775  0.407225
# 2          0.576733  0.423267
# 3          0.757576  0.242424

# %%
# Средний возраст среди мужчин и женщин
age_by_gender = df.pivot_table(index='sex', values='age', aggfunc='mean')
age_by_gender
# Out:
#               age
# sex
# female  28.687071
# male    30.585233
